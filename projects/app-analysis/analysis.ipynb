# %% [markdown]
# # Analysing the app_store and play_store dataset

# %% [markdown]
# This project analyze number of app user based on categoires

# %%
from csv import reader
def open_dataset(dataset):
    open_data = open(dataset)
    read_file = reader(open_data)
    app_list = list(read_file)
    return app_list

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
app_store = explore_data(open_dataset('../../dataset/AppleStore.csv'), 0, 5, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# Number of rows: 7198
# Number of columns: 16

# %%
play_store = explore_data(open_dataset('../../dataset/googleplaystore.csv'), 0, 4, rows_and_columns = True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 10842
# Number of columns: 13

# %%
column_name_app_store = open_dataset('../../dataset/AppleStore.csv')
print(column_name_app_store[0])
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %%
column_name_playstore = open_dataset('../../dataset/googleplaystore.csv')
print(column_name_playstore[0])
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
error_rating = column_name_playstore[10473]
print(error_rating)
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %%
del column_name_playstore[10473]

# %% [markdown]
# # Removing the duplicate data from the playstore dataset
# After careful analysis of data , we find some of the duplicate and we only keep the most recent data from the duplicate and remove all other

# %%
playstore_entry = open_dataset('../../dataset/googleplaystore.csv')
del playstore_entry[10473]

# %%
unique_element = []
duplicate_entry = []

for entry in playstore_entry[1:]:
    name = entry[0]
    if name in unique_element:
        duplicate_entry.append(name)
    else:
        unique_element.append(name)
print(len(unique_element))
print(len(duplicate_entry))
# Out:
# 9659
# 1181

# %%
for row in playstore_entry[1:]:
    name = row[0]
    if name == 'Instagram':
        print(row)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# # We Remove the duplicate using the criterion :
# only keep the value with the  highest number of reviews of apps

# %%
reviews_max = {}
for row in playstore_entry[1:]:
    name = row[0]
    n_reviews = float(row[3])
    if (name in reviews_max) and reviews_max[name] < n_reviews :
        reviews_max[name] = n_reviews
    elif name not in reviews_max:
        reviews_max[name] = n_reviews
print(len(reviews_max))
print(reviews_max['Instagram'])
# Out:
# 9659
# 66577446.0

# %%
android_clean = []
already_added = []
for row in playstore_entry[1:]:
    name = row[0]
    n_reviews = float(row[3])
    if (n_reviews == reviews_max[name]) and name not in already_added:
        android_clean.append(row)
        already_added.append(name)
print(android_clean[:5])
print(len(android_clean))
print(already_added[:5])
# Out:
# [['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up'], ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up'], ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up'], ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up'], ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']]
# 9659
# ...

# %%
def eng_check(string):
    sum = 0
    for char in string:
        if ord(char) > 127:
            sum += 1
        if sum > 3:
            return False
    return True

# %%
print(eng_check('Instagram'))
print(eng_check('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(eng_check('Docs To Go™ Free Office Suite'))
print(eng_check('Instachat 😜'))
# Out:
# True
# False
# True
# True

# %%
Eng_app_playstore = []
for row in android_clean:
    name = row[0]
    if eng_check(name):
        Eng_app_playstore.append(row)
print(len(Eng_app_playstore))
print(Eng_app_playstore[:5])
# Out:
# 9614
# [['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up'], ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up'], ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up'], ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up'], ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']]

# %%
Eng_app_appstore = []
appstore_entry = open_dataset('../../dataset/AppleStore.csv')
for row in  appstore_entry[1:]:
    name = row[1]
    if eng_check(name):
        Eng_app_appstore.append(row)
print(len(Eng_app_appstore))
print(Eng_app_appstore[:5])
# Out:
# 6183
# [['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1'], ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1'], ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1'], ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1'], ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']]

# %%
free_appstore = []
for row in Eng_app_appstore:
    price = float(row[4])
    if price == 0:
        free_appstore.append(row)
print(len(free_appstore))
print(free_appstore[:5])
# Out:
# 3222
# [['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1'], ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1'], ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1'], ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1'], ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']]

# %%
free_playstore = []
for row in Eng_app_playstore:
    price_info = row[6]
    if price_info == 'Free':
        free_playstore.append(row)
print(len(free_playstore))
print(free_playstore[1000:1005])
# Out:
# 8863
# [['Fertility Friend Ovulation App', 'HEALTH_AND_FITNESS', '4.5', '12955', '7.2M', '1,000,000+', 'Free', '0', 'Teen', 'Health & Fitness', 'June 27, 2018', '10.24', '4.4 and up'], ['Pregnancy Tracker', 'HEALTH_AND_FITNESS', '4.1', '2681', '6.5M', '500,000+', 'Free', '0', 'Everyone', 'Health & Fitness', 'February 10, 2018', '37', '4.0.3 and up'], ['Period Tracker', 'HEALTH_AND_FITNESS', '4.5', '325738', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Health & Fitness', 'July 28, 2018', 'Varies with device', 'Varies with device'], ['Spot On Period, Birth Control, & Cycle Tracker', 'HEALTH_AND_FITNESS', '4.6', '4102', '24M', '500,000+', 'Free', '0', 'Everyone 10+', 'Health & Fitness', 'July 19, 2018', '2.6.1', '4.2 and up'], ['OvuView: Ovulation and Fertility', 'HEALTH_AND_FITNESS', '4.5', '40296', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Health & Fitness', 'June 15, 2018', 'Varies with device', 'Varies with device']]

# %%
genre_playstore = {}
for row in free_playstore:
    genre = row[1]
    if genre in genre_playstore:
        genre_playstore[genre] += 1
    else:
        genre_playstore[genre] = 1
print(genre_playstore)
# Out:
# {'ART_AND_DESIGN': 57, 'AUTO_AND_VEHICLES': 82, 'BEAUTY': 53, 'BOOKS_AND_REFERENCE': 190, 'BUSINESS': 407, 'COMICS': 55, 'COMMUNICATION': 287, 'DATING': 165, 'EDUCATION': 103, 'ENTERTAINMENT': 85, 'EVENTS': 63, 'FINANCE': 328, 'FOOD_AND_DRINK': 110, 'HEALTH_AND_FITNESS': 273, 'HOUSE_AND_HOME': 73, 'LIBRARIES_AND_DEMO': 83, 'LIFESTYLE': 346, 'GAME': 862, 'FAMILY': 1675, 'MEDICAL': 313, 'SOCIAL': 236, 'SHOPPING': 199, 'PHOTOGRAPHY': 261, 'SPORTS': 301, 'TRAVEL_AND_LOCAL': 207, 'TOOLS': 750, 'PERSONALIZATION': 294, 'PRODUCTIVITY': 345, 'PARENTING': 58, 'WEATHER': 71, 'VIDEO_PLAYERS': 159, 'NEWS_AND_MAGAZINES': 248, 'MAPS_AND_NAVIGATION': 124}

# %%
genre_appstore = {}
for row in free_appstore:
    genre = row[11]
    if genre in genre_appstore:
        genre_appstore[genre] += 1
    else:
        genre_appstore[genre] = 1
print(genre_appstore)
# Out:
# {'Social Networking': 106, 'Photo & Video': 160, 'Games': 1874, 'Music': 66, 'Reference': 18, 'Health & Fitness': 65, 'Weather': 28, 'Utilities': 81, 'Travel': 40, 'Shopping': 84, 'News': 43, 'Navigation': 6, 'Lifestyle': 51, 'Entertainment': 254, 'Food & Drink': 26, 'Sports': 69, 'Book': 14, 'Finance': 36, 'Education': 118, 'Productivity': 56, 'Business': 17, 'Catalogs': 4, 'Medical': 6}

# %%
def freq_table(dataset, index):
    table = {}
    total = 0
    for row in dataset:
        total += 1
        genre = row[index]
        if genre in table:
            table[genre] += 1
        else:
            table[genre] = 1
    table_percent = {}
    for key in table:
        table_percent[key] = (table[key]/total) * 100
    return table_percent

# %%
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
display_table(free_playstore, 1)
# Out:
# FAMILY : 18.898792733837304
# GAME : 9.725826469592688
# TOOLS : 8.462146000225657
# BUSINESS : 4.592124562789123
# LIFESTYLE : 3.9038700214374367
# PRODUCTIVITY : 3.8925871601038025
# FINANCE : 3.7007785174320205
# MEDICAL : 3.5315355974275078
# SPORTS : 3.396141261423897
# PERSONALIZATION : 3.317161232088458
# COMMUNICATION : 3.2381812027530184
# HEALTH_AND_FITNESS : 3.0802211440821394
# PHOTOGRAPHY : 2.944826808078529
# NEWS_AND_MAGAZINES : 2.798149610741284
# SOCIAL : 2.6627552747376737
# TRAVEL_AND_LOCAL : 2.335552296062281
# SHOPPING : 2.245289405393208
# BOOKS_AND_REFERENCE : 2.1437436533904997
# DATING : 1.8616721200496444
# VIDEO_PLAYERS : 1.7939749520478394
# MAPS_AND_NAVIGATION : 1.399074805370642
# FOOD_AND_DRINK : 1.241114746699763
# EDUCATION : 1.1621347173643235
# ENTERTAINMENT : 0.9590432133589079
# LIBRARIES_AND_DEMO : 0.9364774906916393
# AUTO_AND_VEHICLES : 0.9251946293580051
# HOUSE_AND_HOME : 0.8236488773552973
# WEATHER : 0.8010831546880289
# ...

# %%
display_table(free_appstore, 11)
# Out:
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %%
genre_appstore = freq_table(free_appstore, 11)
for genre in genre_appstore:
    total = 0 
    len_genre = 0
    for row in free_appstore:
        genre_app = row[11]
        if genre_app == genre:
            total += float(row[5])
            len_genre += 1
       
    average = total / len_genre
    print(genre , ':' , average)
# Out:
# Social Networking : 71548.34905660378
# Photo & Video : 28441.54375
# Games : 22788.6696905016
# Music : 57326.530303030304
# Reference : 74942.11111111111
# Health & Fitness : 23298.015384615384
# Weather : 52279.892857142855
# Utilities : 18684.456790123455
# Travel : 28243.8
# Shopping : 26919.690476190477
# News : 21248.023255813954
# Navigation : 86090.33333333333
# Lifestyle : 16485.764705882353
# Entertainment : 14029.830708661417
# Food & Drink : 33333.92307692308
# Sports : 23008.898550724636
# Book : 39758.5
# Finance : 31467.944444444445
# Education : 7003.983050847458
# Productivity : 21028.410714285714
# Business : 7491.117647058823
# Catalogs : 4004.0
# Medical : 612.0

# %%
genre_playstore = freq_table(free_playstore, 1)
for genre in genre_playstore:
    total = 0 
    len_genre = 0
    for row in free_playstore:
        genre_app = row[1]
        if genre_app == genre:
            install = row[5]
            install = install.replace('+', '')
            install = install.replae(',', '')
            total += float(install)
            len_genre += 1
       
    average = total / len_genre
    print(genre , ':' , average)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [54], in <cell line: 0>()
#       8 install = row[5]
#       9 install = install.replace('+', '')
# ---> 10 install = install.replcae(',', '')
#      11 total += float(install)
#      12 len_genre += 1
#
# AttributeError: 'str' object has no attribute 'replcae'
